# %% [markdown]
# # NLTK - Text Mining

# %% [markdown]
# * Exploraremos recursos da nltk
# * Recursos para trabalhar com NLP
# * Abordaremos as features da biblioteca com corpus da própria nltk.
# * Aplicaremos a NLTK em uma base de dados real

# %% [markdown]
# **Importe a Biblioteca NLTK**

# %%
import nltk

# %% [markdown]
# **Faça download da base de corpus da nltk**

# %%
# nltk.download()

# %%
from IPython.display import Image
Image('nltk-downloader.jpg')

# %% [markdown]
# ** Importe o corpus brown e imprime suas categorias**

# %% [markdown]
# * Corpus com milhares de palavras de várias categorias

# %%
from nltk.corpus import brown

# %%
brown.categories()
# Out:
# ['adventure',
#  'belles_lettres',
#  'editorial',
#  'fiction',
#  'government',
#  'hobbies',
#  'humor',
#  'learned',
#  'lore',
#  'mystery',
#  'news',
#  'religion',
#  'reviews',
#  'romance',
#  'science_fiction']

# %%
len(brown.words())
# Out:
# 1161192

# %%
len(brown.words(categories='news'))
# Out:
# 100554

# %% [markdown]
# ** Visualizando sentenças da categoria romance**

# %%
brown.sents(categories=['romance'])
# Out:
# [['They', 'neither', 'liked', 'nor', 'disliked', 'the', 'Old', 'Man', '.'], ['To', 'them', 'he', 'could', 'have', 'been', 'the', 'broken', 'bell', 'in', 'the', 'church', 'tower', 'which', 'rang', 'before', 'and', 'after', 'Mass', ',', 'and', 'at', 'noon', ',', 'and', 'at', 'six', 'each', 'evening', '--', 'its', 'tone', ',', 'repetitive', ',', 'monotonous', ',', 'never', 'breaking', 'the', 'boredom', 'of', 'the', 'streets', '.'], ...]

# %% [markdown]
# ** Quantidade de sentenças da categoria**

# %%
len(brown.sents(categories=['romance']))
# Out:
# 4431

# %% [markdown]
# **Obtem as palavras do corpus**

# %%
brown.words()
# Out:
# ['The', 'Fulton', 'County', 'Grand', 'Jury', 'said', ...]

# %%
#obtem as palavras do corpus romance
palavras=brown.words(categories=['romance'])

# %%
palavras
# Out:
# ['They', 'neither', 'liked', 'nor', 'disliked', 'the', ...]

# %%
len(palavras)
# Out:
# 70022

# %% [markdown]
# ** Obter a frequencia de palavras**

# %%
#obter a frequencia de cada palavra
fdist=nltk.FreqDist(p.lower() for p in palavras)

# %%
fdist
# Out:
# FreqDist({',': 3899, '.': 3736, 'the': 2988, 'and': 1905, 'to': 1517, 'a': 1383, 'of': 1202, 'he': 1068, '``': 1045, "''": 1044, ...})

# %%
fdist.most_common(20)
# Out:
# [(',', 3899),
#  ('.', 3736),
#  ('the', 2988),
#  ('and', 1905),
#  ('to', 1517),
#  ('a', 1383),
#  ('of', 1202),
#  ('he', 1068),
#  ('``', 1045),
#  ("''", 1044),
#  ('was', 999),
#  ('i', 951),
#  ('in', 930),
#  ('she', 728),
#  ('it', 717),
#  ('had', 695),
#  ('?', 690),
#  ('her', 680),
#  ('that', 612),
#  ('his', 603)]

# %% [markdown]
# **Palavras ordenadas por ordem alfabética**

# %%
sorted(set(palavras))[:50]
# Out:
# ['!',
#  '&',
#  "'",
#  "''",
#  "'ello",
#  "'em",
#  "'most",
#  '(',
#  ')',
#  ',',
#  '--',
#  '.',
#  '10',
#  '141',
#  '160',
#  '1935',
#  '1936',
#  '1938',
#  '1940',
#  '1944',
#  '230',
#  '3',
#  '4000-plus',
#  "6'",
#  ':',
#  ';',
#  '?',
#  'A',
#  "A's",
#  'A-Z',
#  "A-Z's",
#  'A.M.',
#  'A40-AjK',
#  'AA',
#  'Abernathy',
#  'Abernathys',
#  'About',
#  'Above',
#  'Abruptly',
#  'Absolution',
#  'Acala',
#  'Across',
#  'Acting',
#  'Actually',
#  'Adam',
#  'Adams',
#  'Adele',
#  'Adelia',
#  'Adrien',
#  'African']

# %% [markdown]
# **Obtem a frequencia de uma palavra no corpus**

# %%
palavras.count('love')
# Out:
# 32

# %%
palavras.count('hate')
# Out:
# 9

# %% [markdown]
# ** Descobrindo a frequencia em percentual de uma palavra no texto**

# %%
def palavra_percentual(freq, dataset):
    total=len(dataset)
    return 100*freq/total

# %%
palavra_percentual(palavras.count('love'), palavras)
# Out:
# 0.04569992288138014

# %% [markdown]
# ** Transforma palavras em objeto texto **
# * Para isso deve-se passar uma lista de palavras para essa classe

# %%
palavras=nltk.Text(palavras)

# %%
type(palavras)
# Out:
# nltk.text.Text

# %% [markdown]
# ** Imprime palavras similares**

# %%
# Imprime as palavras mais similares por contexto.

# %%
palavras.similar('love',num=30)
# Out:
# see that it place know tell want help understand telling hate man he
# there him above name one but her way said thought herself get be
# remember did through though

# %% [markdown]
# ** Conjuntos de Palavras empregadas similarmente**

# %%
print(';'.join(palavras.collocation_list()))
# Out:
# New York;Old Man;Mike Deegan;Cousin Elec;Lucille Warren;old man;Poor John;Cousin Emma;Gratt Shafer;I've got;Mrs. Kirby;could see;Eddie Lee;Hanford College;young men;Miss Jen;Mr. Willis;Early Spring;Mrs. Salter;Gertrude Parker

# %% [markdown]
# ** Concordancia das palavras**

# %%
# Contexto na qual a palavra aparece

# %%
palavras.concordance('love')
# Out:
# Displaying 25 of 36 matches:
# yards in which no one knew privacy . Love and hatred and fear were one here ,
# l leave you '' . `` Sounds like real love '' , Owen said . `` It sort of bring
#  to satisfy any egotist . It was for love that he had served the Navy . To hav
# rved the Navy . To have someday that love returned was what he had lived for .
# is not having the only man you could love , whether he drives a bread truck or
#  you can stay alive and hate him and love him and want him even if it means yo
# e him , not even with God . If it is love , you don't . And I'll take you with
# her woman , the one that never could love him the way you do , the one who got
# ts women under stress indulge in . I love you , I hate you , I feel like killi
#  myself , and in the same sequence I love you I think you're the most wonderfu
# t , I can understand that by now and love them still , because everyone must j
#  of women in towns , dispossessed of love , hanging on to makeshifts , and alt
# d like the tails of sage hens making love . Walitzee whitened his leggings wit
# said , jollying Lucy a little . `` I love you . Susan ready '' ? ? Lucy listen
# e said , and the single word mingled love and exasperation in an equal blend .
# g gave her as a token of his undying love . `` You going to marry the King ''
#  the aqua-lung I could swim better , love my woman better . I chuckled aloud ,
# anger in her . We undressed and made love with the comfortable acceptance I ha
#  Sue baby '' , he'd said . Much as I love you -- well , a guy's a guy and Luci
# arren . But it didn't seem fair . My love for Johnnie was young and clean -- h
# oved me and wanted me . But the only love I was giving him was the pure kind .
# , we both knew we were hopelessly in love . Yet even then we did nothing much
# hnnie and I had been innocent in our love , and that was the way I wanted to k
#  darkness , begging this man to make love to me . `` Love me , Johnnie '' . ``
# ing this man to make love to me . `` Love me , Johnnie '' . `` I will , kitten

# %% [markdown]
# ** Empregabilidade comuns das palavras **

# %%
palavras.common_contexts(['love','hate'])
# Out:
# and_him i_you

# %% [markdown]
# ** Disperção Léxica de palavras no dataset**

# %%
# %matplotlib notebook
palavras.dispersion_plot(['love','hate','man'])
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# # Aplicando NLTK em uma base de dados real

# %% [markdown]
# * Usaremos uma base de dados real de tweets sobre o governo de Minas Gerais
# * O twitter é um serviço muito utilizado por empresas para análises
# * Trabalhar com o idioma portugues ainda é um desafio

# %%
from IPython.display import Image
Image('twitter_5.png',width=600, height=400)

# %% [markdown]
# **Ler a base de dados**

# %%
import pandas as pd

# %%
tweets=pd.read_csv(r'C:\Users\Daniel\NaiveBayes-Materiais-de-Apoio\NaiveBayes-Materiais-de-Apoio\Tweets_Mg.csv')

# %%
tweets.head()
# Out:
#    Unnamed: 0                      Created At  \
# 0           0  Sun Jan 08 01:22:05 +0000 2017
# 1           1  Sun Jan 08 01:49:01 +0000 2017
# 2           2  Sun Jan 08 01:01:46 +0000 2017
# 3           3  Wed Jan 04 21:43:51 +0000 2017
# 4           4  Mon Jan 09 15:08:21 +0000 2017
#
#                                                 Text  \
# 0  ���⛪ @ Catedral de Santo Antônio - Governador ...
# 1  � @ Governador Valadares, Minas Gerais https:/...
# 2  �� @ Governador Valadares, Minas Gerais https:...
# 3                        ��� https://t.co/BnDsO34qK0
# 4  ��� PSOL vai questionar aumento de vereadores ...
#
#    Geo Coordinates.latitude  Geo Coordinates.longitude User Location  \
# 0                       NaN                        NaN        Brasil
# 1                  -41.9333                     -18.85           NaN
# 2                  -41.9333                     -18.85           NaN
# 3                       NaN                        NaN           NaN
# 4                       NaN                        NaN           NaN
#
#                Username User Screen Name  Retweet Count Classificacao  ...  \
# 0  Leonardo C Schneider    LeoCSchneider              0        Neutro  ...
# 1               Wândell         klefnews              0        Neutro  ...
# 2               Wândell         klefnews              0        Neutro  ...
# 3         Ana estudando  estudandoconcur              0        Neutro  ...
# 4                 Emily         Milly777              0      Negativo  ...
#
#   Unnamed: 15  Unnamed: 16  Unnamed: 17  Unnamed: 18  Unnamed: 19  \
# 0         NaN          NaN          NaN          NaN          NaN
# 1         NaN          NaN          NaN          NaN          NaN
# 2         NaN          NaN          NaN          NaN          NaN
# 3         NaN          NaN          NaN          NaN          NaN
# 4         NaN          NaN          NaN          NaN          NaN
#
#    Unnamed: 20  Unnamed: 21  Unnamed: 22  Unnamed: 23  Unnamed: 24
# 0          NaN          NaN          NaN          NaN          NaN
# 1          NaN          NaN          NaN          NaN          NaN
# 2          NaN          NaN          NaN          NaN          NaN
# 3          NaN          NaN          NaN          NaN          NaN
# 4          NaN          NaN          NaN          NaN          NaN
#
# [5 rows x 26 columns]

# %%
tweets.Text.head(20)
# Out:
# 0     ���⛪ @ Catedral de Santo Antônio - Governador ...
# 1     � @ Governador Valadares, Minas Gerais https:/...
# 2     �� @ Governador Valadares, Minas Gerais https:...
# 3                           ��� https://t.co/BnDsO34qK0
# 4     ��� PSOL vai questionar aumento de vereadores ...
# 5     " bom é bandido morto"\nDeputado Cabo Júlio é ...
# 6     "..E 25% dos mineiros dizem não torcer para ti...
# 7     "A gigantesca barba do mal" em destaque no cad...
# 8     "BB e governo de Minas travam disputa sobre de...
# 9     "com vcs bh fica pequena!" Belo Horizonte (pro...
# 10    "Daí a gente visita governador valadares"\n"Qu...
# 11    "É bonita e é bonita..." \n#latergram #ibituru...
# 12    "erro desconhecido" é mato! Aliás, é da secret...
# 13    "La La Land: Cantando Estações" arrasa no Glob...
# 14    "La La Land: Cantando Estações" arrasa no Glob...
# 15    "Los abusos, aun en el estado más sólido, son ...
# 16    "Mesmo sem muito dinheiro no caixa o governo d...
# 17    "Modelo de segurança será o nosso legado", diz...
# 18    "Modelo de segurança será o nosso legado", diz...
# 19    "Modelo de segurança será o nosso legado", diz...
# Name: Text, dtype: object

# %%
tweets.count()
# Out:
# Unnamed: 0                   8199
# Created At                   8199
# Text                         8199
# Geo Coordinates.latitude      104
# Geo Coordinates.longitude     104
# User Location                5489
# Username                     8199
# User Screen Name             8199
# Retweet Count                8199
# Classificacao                8199
# Observação                      1
# Unnamed: 10                     0
# Unnamed: 11                     0
# Unnamed: 12                     0
# Unnamed: 13                     0
# Unnamed: 14                     0
# Unnamed: 15                     0
# Unnamed: 16                     0
# Unnamed: 17                     0
# Unnamed: 18                     0
# Unnamed: 19                     0
# Unnamed: 20                     0
# Unnamed: 21                     0
# Unnamed: 22                     0
# Unnamed: 23                     0
# Unnamed: 24                     0
# dtype: int64

# %% [markdown]
# **Tokenization dos tweets**

# %% [markdown]
# * Tokenização é a capacidade de reconhecer palavras e sentenças em uma frase ou texto.
# * Existem diversos tipos de tokenizadores.
# * Conheça o domínio na qual voce está trabalhando.

# %%
import nltk
from nltk.tokenize import word_tokenize

# %%
from nltk.tokenize import TweetTokenizer

# %% [markdown]
# * Gera uma lista de palavras a partir dos tokens ou termos da base de dados.

# %%
from functools import reduce
import operator

list_palavras=[]
for t in tweets.Text.items():
    list_palavras.append(t[1].split())
    
#Reduz a lista de listas em apenas uma lista única de elementos
list_palavras=reduce(operator.concat, list_palavras)
list_palavras[:50]
# Out:
# ['���⛪',
#  '@',
#  'Catedral',
#  'de',
#  'Santo',
#  'Antônio',
#  '-',
#  'Governador',
#  'Valadares/MG',
#  'https://t.co/JSbKamIqUJ',
#  '�',
#  '@',
#  'Governador',
#  'Valadares,',
#  'Minas',
#  'Gerais',
#  'https://t.co/B3ThIDJCSf',
#  '��',
#  '@',
#  'Governador',
#  'Valadares,',
#  'Minas',
#  'Gerais',
#  'https://t.co/dPkgzVR2Qw',
#  '���',
#  'https://t.co/BnDsO34qK0',
#  '���',
#  'PSOL',
#  'vai',
#  'questionar',
#  'aumento',
#  'de',
#  'vereadores',
#  'e',
#  'prefeito',
#  'de',
#  'BH',
#  'na',
#  'Justiça',
#  '-',
#  'Politica',
#  '-',
#  'Estado',
#  'de',
#  'Minas',
#  'https://t.co/DMg7BGsek5',
#  '"',
#  'bom',
#  'é',
#  'bandido']

# %%
len(list_palavras)
# Out:
# 132341

# %% [markdown]
# **Gera um objeto do tipo *nltk.Text* a partir da lista de palavras.**

# %%
tweets_text_nltk=nltk.Text(list_palavras)

# %% [markdown]
# **Imprime tokens**

# %%
tweets_text_nltk.tokens
# Out:
# ['���⛪',
#  '@',
#  'Catedral',
#  'de',
#  'Santo',
#  'Antônio',
#  '-',
#  'Governador',
#  'Valadares/MG',
#  'https://t.co/JSbKamIqUJ',
#  '�',
#  '@',
#  'Governador',
#  'Valadares,',
#  'Minas',
#  'Gerais',
#  'https://t.co/B3ThIDJCSf',
#  '��',
#  '@',
#  'Governador',
#  'Valadares,',
#  'Minas',
#  'Gerais',
#  'https://t.co/dPkgzVR2Qw',
#  '���',
#  'https://t.co/BnDsO34qK0',
#  '���',
#  'PSOL',
#  'vai',
#  'questionar',
#  'aumento',
#  'de',
#  'vereadores',
#  'e',
#  'prefeito',
#  'de',
#  'BH',
#  'na',
#  'Justiça',
#  '-',
#  'Politica',
#  '-',
#  'Estado',
#  'de',
#  'Minas',
#  'https://t.co/DMg7BGsek5',
#  '"',
#  'bom',
#  'é',
#  'bandido',
#  'morto"',
#  'Deputado',
#  'Cabo',
#  'Júlio',
#  'é',
#  'condenado',
#  'e',
#  'fica',
#  'inelegível',
#  'por',
#  '10',
#  'anos',
#  '-',
#  'Politica',
#  '-',
#  'Estado',
#  'de',
#  'Minas',
#  'https://t.co/3GfAqvrFHS',
#  '"..E',
#  '25%',
#  'dos',
#  'mineiros',
#  'dizem',
#  'não',
#  'torcer',
#  'para',
#  'time',
#  'nenhum,mesmo',
#  'dentro',
#  'de',
#  'um',
#  'estado',
#  'com',
#  'Atlético-MG',
#  'e',
#  'Cruzeiro.',
#  'Pq?.."',
#  'https://t.co/fN5evlLQsR',
#  '"A',
#  'gigantesca',
#  'barba',
#  'do',
#  'mal"',
#  'em',
#  'destaque',
#  'no',
#  'caderno',
#  'Cultura',
#  'do',
#  'Estado',
#  'de',
#  'Minas.',
#  'https://t.co/PxNurIkTlw',
#  '"BB',
#  'e',
#  'governo',
#  'de',
#  'Minas',
#  'travam',
#  'disputa',
#  'sobre',
#  'depósitos',
#  'judiciais"',
#  'https://t.co/CnMu2A2Qo5',
#  '"com',
#  'vcs',
#  'bh',
#  'fica',
#  'pequena!"',
#  'Belo',
#  'Horizonte',
#  '(pron.',
#  '[bɛloɾiˈzõntʃi][10])',
#  'é',
#  'a',
#  'capital',
#  'do',
#  'estado',
#  'de',
#  'MG,',
#  'com',
#  'uma',
#  'área',
#  'de',
#  'aproximadamente',
#  '331',
#  'km²',
#  '"Daí',
#  'a',
#  'gente',
#  'visita',
#  'governador',
#  'valadares"',
#  '"Que',
#  'lugar',
#  'eh',
#  'esse',
#  'mãe?"',
#  '"MG,',
#  'a',
#  'gente',
#  'tem',
#  'uns',
#  'parente',
#  'la"',
#  'MANO',
#  'onde',
#  'q',
#  'eu',
#  'NÃO',
#  'tenho',
#  'parente',
#  '"É',
#  'bonita',
#  'e',
#  'é',
#  'bonita..."',
#  '#latergram',
#  '#ibituruna',
#  '#home',
#  '@',
#  'Governador',
#  'Valadares,',
#  'Minas',
#  'Gerais',
#  'https://t.co/y12TtNqpnH',
#  '"erro',
#  'desconhecido"',
#  'é',
#  'mato!',
#  'Aliás,',
#  'é',
#  'da',
#  'secretaria',
#  'estadual',
#  'de',
#  'fazenda',
#  'que',
#  'tá',
#  'assim...',
#  'MG',
#  'não',
#  'precisa',
#  'de',
#  'dinheiro',
#  'não,',
#  'Governador?',
#  '"La',
#  'La',
#  'Land:',
#  'Cantando',
#  'Estações"',
#  'arrasa',
#  'no',
#  'Globo',
#  'de',
#  'Ouro',
#  '-',
#  'Estado',
#  'de',
#  'Minas',
#  'https://t.co/aQ0NG1bp5f',
#  'https://t.co/aY3qlrVnTE',
#  '"La',
#  'La',
#  'Land:',
#  'Cantando',
#  'Estações"',
#  'arrasa',
#  'no',
#  'Globo',
#  'de',
#  'Ouro',
#  '-',
#  'Estado',
#  'de',
#  'Minas',
#  'https://t.co/qRI9DCiicc',
#  '"Los',
#  'abusos,',
#  'aun',
#  'en',
#  'el',
#  'estado',
#  'más',
#  'sólido,',
#  'son',
#  'minas',
#  'sordas',
#  'que',
#  'tarde',
#  'o',
#  'temprano',
#  'estallan"',
#  'Joseph',
#  'Sanial-Dubay',
#  '"Mesmo',
#  'sem',
#  'muito',
#  'dinheiro',
#  'no',
#  'caixa',
#  'o',
#  'governo',
#  'de',
#  'Minas',
#  'Gerais',
#  'compra',
#  '2',
#  '(DOIS)',
#  'helicópteros."',
#  'Dois...',
#  'Helicópteros...',
#  'Minas',
#  'Gerais...',
#  '#2017',
#  's1',
#  '"Modelo',
#  'de',
#  'segurança',
#  'será',
#  'o',
#  'nosso',
#  'legado",',
#  'diz',
#  'Cláudio',
#  'Beato',
#  '-',
#  'Politica',
#  '-',
#  'Estado',
#  'de',
#  'Minas',
#  'https://t.co/1MqOJo7Nnf',
#  '"Modelo',
#  'de',
#  'segurança',
#  'será',
#  'o',
#  'nosso',
#  'legado",',
#  'diz',
#  'Cláudio',
#  'Beato',
#  '-',
#  'Politica',
#  '-',
#  'Estado',
#  'de',
#  'Minas',
#  'https://t.co/kA09mEn4xN',
#  '"Modelo',
#  'de',
#  'segurança',
#  'será',
#  'o',
#  'nosso',
#  'legado",',
#  'diz',
#  'Cláudio',
#  'Beato',
#  '-',
#  'Politica',
#  '-',
#  'Estado',
#  'de',
#  'Minas',
#  'https://t.co/S97Khxldiu',
#  '"O',
#  'governo',
#  'de',
#  'Minas',
#  'Gerais',
#  'não',
#  'comentou',
#  'o',
#  'assunto.',
#  '"',
#  'https://t.co/SNYMRfQ737',
#  '"O',
#  'governo',
#  'federal',
#  'publicou',
#  'no',
#  'dia',
#  '27',
#  'de',
#  'dezembro',
#  'de',
#  '2016,',
#  'a',
#  'Medida',
#  'Provisória',
#  '764/16',
#  'que',
#  'permite',
#  'a',
#  'diferenciação...',
#  'https://t.co/0DlDpZ9WGz',
#  '"Polícia',
#  'Federal',
#  'acaba',
#  'de',
#  'divulgar',
#  'que',
#  'encontrou',
#  'provas',
#  'no',
#  'apartamento',
#  'do',
#  'Lula,',
#  'mas',
#  'só',
#  'até',
#  'a',
#  '4ª',
#  'série."',
#  'Jornal',
#  'Estado',
#  'de',
#  'Minas',
#  '"Praia',
#  'da',
#  'Estação"',
#  'lota',
#  'neste',
#  'sábado',
#  'de',
#  'verão',
#  'em',
#  'BH',
#  '-',
#  'Gerais',
#  '-',
#  'Estado',
#  'de',
#  'Minas',
#  'https://t.co/DpG3CNfZBb',
#  '"Representando',
#  'mais',
#  'uma',
#  'ferramenta',
#  'de',
#  'monitoramento',
#  'da',
#  'educação',
#  'da',
#  'rede',
#  'estadual',
#  'em',
#  'Minas,',
#  'a',
#  'Secretaria',
#  'de',
#  'Estado...',
#  'https://t.co/brsfBqHXlQ',
#  '"uso',
#  'de',
#  'aeronave',
#  'pertencente',
#  'ao',
#  'Estado',
#  'de',
#  'MG,',
#  'em',
#  'domingo,',
#  'p/',
#  'fins',
#  'pessoais,',
#  'em',
#  'claro',
#  'desvio',
#  'de',
#  'finalidade"',
#  '-',
#  'https://t.co/WEfv5iLyju',
#  '"vou',
#  'postar',
#  'umas',
#  'curiosidades',
#  'sobre',
#  'o',
#  'corpo',
#  'humano"',
#  '*o',
#  'Japão',
#  'é',
#  'menor',
#  'que',
#  'o',
#  'estado',
#  'de',
#  'minas',
#  'gerais*',
#  '????¿¿¿.?¿',
#  '#ACORDAMINAS!!!',
#  'O',
#  'governador',
#  'Fernando',
#  'Pimentel,',
#  'depois',
#  'de',
#  'ser',
#  'flagrado',
#  'usando',
#  'um',
#  'helicóptero',
#  'do',
#  'Estado',
#  'de',
#  'MG...',
#  'https://t.co/bedW4w4jij',
#  '#ACORDAMINAS!!!!',
#  'O',
#  'povo',
#  'mineiro',
#  'tem',
#  'que',
#  'da',
#  'um',
#  'pé',
#  'na',
#  'bunda',
#  'desse',
#  'canalha...',
#  'https://t.co/ZKZNVmyXbg',
#  '#Alerta',
#  '-',
#  'Nome',
#  'da',
#  'CEEE',
#  'é',
#  'utilizado',
#  'em',
#  'golpe',
#  'no',
#  'Estado.',
#  'https://t.co/i5ndsWhXR4',
#  'https://t.co/yaEM6s3Z2f',
#  '#beta',
#  '#betalab',
#  '#mg',
#  'Afiliada',
#  'da',
#  'Globo:',
#  'Apresentador',
#  'no',
#  'AM',
#  'é',
#  'demitido',
#  'após',
#  'criticar',
#  'governador…',
#  'https://t.co/hlH8ITxXig',
#  '#beta',
#  '#betalab',
#  '#mg',
#  'Caos',
#  'nos',
#  'presídios:',
#  'AM',
#  'pede',
#  'apoio',
#  'à',
#  'União',
#  'seis',
#  'dias',
#  'após',
#  'massacre',
#  'https://t.co/GRv0HkrX3T…',
#  'https://t.co/YJy2RcSfWZ',
#  '#beta',
#  '#betalab',
#  '#mg',
#  'Caos',
#  'nos',
#  'presídios:',
#  'Temer',
#  'e',
#  'Cármen',
#  'Lúcia',
#  'se',
#  'reúnem',
#  'para',
#  'debater',
#  'crise',
#  'https://t.co/e34RNvtU7v…',
#  'https://t.co/8xKwPTOv4C',
#  '#beta',
#  '#betalab',
#  '#mg',
#  'Crise',
#  'carcerária:',
#  'Governo',
#  'de',
#  'Roraima',
#  'pede',
#  'Força',
#  'Nacional',
#  'a',
#  'Temer',
#  'https://t.co/wLslS1T6ZI…',
#  'https://t.co/NK4c5IhNUg',
#  '#beta',
#  '#betalab',
#  '#mg',
#  'Crise',
#  'carcerária:',
#  'Secretário',
#  'de',
#  'SP',
#  'diz',
#  'haver',
#  'guerra',
#  'de',
#  'facções',
#  'no',
#  'país',
#  'https://t.co/RSf2Tk1VmX…',
#  'https://t.co/Sonel0f8Xq',
#  '#beta',
#  '#betalab',
#  '#mg',
#  'Crise',
#  'política',
#  'no',
#  'DF',
#  'se',
#  'agrava:',
#  'Rollemberg',
#  'exonera',
#  'vice-governador',
#  'de',
#  'cargo…',
#  'https://t.co/idJfAELeW4',
#  '#timbeta',
#  '#rt',
#  '#brasil',
#  '#beta',
#  '#betalab',
#  '#mg',
#  'Escalada',
#  'de',
#  'violência',
#  'nos',
#  'presídios:',
#  'AM',
#  'pede',
#  'apoio',
#  'da',
#  'Força',
#  'Nacional;…',
#  'https://t.co/ysX8TXSm50…',
#  'https://t.co/NAly4Uxb5h',
#  '#beta',
#  '#betalab',
#  '#mg',
#  'Escalada',
#  'de',
#  'violência:',
#  'Crime',
#  'organizado',
#  'no',
#  'Brasil',
#  'é',
#  'disputado',
#  'por',
#  '27…',
#  'https://t.co/loRe3EfGaF…',
#  'https://t.co/sSY5liKfMl',
#  '#beta',
#  '#betalab',
#  '#mg',
#  'Estado',
#  'afirma',
#  'não',
#  'ter',
#  'sido',
#  'notificado:',
#  'Apesar',
#  'de',
#  'decisão',
#  'judicial,',
#  'reajuste……',
#  'https://t.co/IMG9Vxs4nK',
#  '#beta',
#  '#betalab',
#  '#mg',
#  'Estado',
#  'de',
#  'espírito',
#  'do',
#  'paulistano:',
#  '"Voz"',
#  'do',
#  'trânsito,',
#  'buzina',
#  'reflete',
#  'pressa,……',
#  'https://t.co/hvLy03lyt3',
#  '#beta',
#  '#betalab',
#  '#mg',
#  'Estados',
#  'falidos:',
#  'Parte',
#  'do',
#  'PMDB',
#  'quer',
#  'barrar',
#  'vetos',
#  'de',
#  'Temer',
#  'na',
#  'negociação',
#  'de……',
#  'https://t.co/h9KQvBYlYV',
#  '#beta',
#  '#betalab',
#  '#mg',
#  'Ex-ministro',
#  'e',
#  'outros:',
#  'Servidores',
#  'da',
#  'era',
#  'PT',
#  'se',
#  'mantêm',
#  'em',
#  'cargos',
#  'estratégicos…',
#  'https://t.co/Q2Nor97ngg',
#  '#timbeta',
#  '#rt',
#  '#brasil',
#  '#beta',
#  '#betalab',
#  '#mg',
#  'Ex-presidente',
#  'da',
#  'Câmara:',
#  'Justiça',
#  'suíça',
#  'vê',
#  "'indícios",
#  "concretos'",
#  'contra…',
#  'https://t.co/fwuwi8S4oD…',
#  'https://t.co/w1W2SaN172',
#  '#beta',
#  '#betalab',
#  '#mg',
#  'Governo',
#  'em',
#  'calamidade',
#  'financeira:',
#  'BB',
#  'avisa',
#  'Justiça',
#  'que',
#  'Minas',
#  'não',
#  'tem…',
#  'https://t.co/CdXt0cvcuY…',
#  'https://t.co/s8un5iFnQS',
#  '#beta',
#  '#betalab',
#  '#mg',
#  'Mais',
#  'sobre',
#  'o',
#  'massacre:',
#  'PF:',
#  'Facção',
#  'tinha',
#  "'cela",
#  'de',
#  "comando'",
#  'dentro',
#  'da',
#  'prisão…',
#  'https://t.co/W3Cr89L0dk',
#  '#beta',
#  '#betalab',
#  '#mg',
#  'Marketing',
#  'e',
#  'veto',
#  'a',
#  'medidas',
#  'de',
#  'Paes:',
#  'De',
#  'doação',
#  'de',
#  'sangue',
#  'a',
#  'capoeira:',
#  'a',
#  '1ª……',
#  'https://t.co/xPnt6omym6',
#  '#beta',
#  '#betalab',
#  '#mg',
#  'Massacre',
#  'em',
#  'presídio',
#  'de',
#  'Manaus:',
#  'Governo',
#  'do',
#  'AM',
#  'rebate',
#  'ministro',
#  'da',
#  'Justiça',
#  'e…',
#  'https://t.co/MaBb4airMU',
#  '#timbeta',
#  '#rt',
#  '#brasil',
#  '#beta',
#  '#betalab',
#  '#mg',
#  'Mudanças',
#  'propostas',
#  'pelo',
#  'governo:',
#  'Reforma',
#  'libera',
#  'trabalhar',
#  '12',
#  'horas',
#  'alguns……',
#  'https://t.co/eIDgx5Ak3n',
#  '#beta',
#  '#betalab',
#  '#mg',
#  'Muitas',
#  'páginas',
#  'de',
#  'investigação:',
#  '"QG"',
#  'da',
#  'Lava',
#  'Jato',
#  'reúne',
#  'mais',
#  'de',
#  '30',
#  'milhões……',
#  'https://t.co/pQF48BKPMr',
#  '#beta',
#  '#betalab',
#  '#mg',
#  'Nos',
#  'últimos',
#  'dois',
#  'anos:',
#  'Governo',
#  'pagou',
#  'R$',
#  '2,4',
#  'bi',
#  'a',
#  'alvos',
#  'da',
#  'Lava',
#  'Jato',
#  'https://t.co/KN8C0LcReb…',
#  'https://t.co/GDQVhjO1Hc',
#  '#beta',
#  '#betalab',
#  '#mg',
#  'Nova',
#  'chacina',
#  'em',
#  'presídio:',
#  'PCC',
#  'matou',
#  'presos',
#  'sem',
#  'facção,',
#  'diz',
#  'governo',
#  'de',
#  'RR',
#  'https://t.co/e17QVKbWVV…',
#  'https://t.co/HJinQ9Y8aT',
#  '#beta',
#  '#betalab',
#  '#mg',
#  'Onda',
#  'de',
#  'violência',
#  'nos',
#  'presídios:',
#  'Governo',
#  'de',
#  'Roraima',
#  'divulga',
#  'lista',
#  'oficial……',
#  'https://t.co/HLcGf3UtCx',
#  '#beta',
#  '#betalab',
#  '#mg',
#  'Pede',
#  'respeito',
#  'aos',
#  'direitos',
#  'dos',
#  'detentos:',
#  'Defensoria',
#  'Pública',
#  'da',
#  'União',
#  'vai',
#  'ao……',
#  'https://t.co/kKbLNKRXfi',
#  '#beta',
#  '#betalab',
#  '#mg',
#  'Pedido',
#  'ao',
#  'STF',
#  'irritou',
#  'Meirelles:',
#  'Governo',
#  'ameaça',
#  'suspender',
#  'aval',
#  'para…',
#  'https://t.co/cHJbFIKAOY…',
#  'https://t.co/uSTdKS5mCn',
#  '#beta',
#  '#betalab',
#  '#mg',
#  'Reforma',
#  'no',
#  'poder',
#  'da',
#  'Venezuela:',
#  'Maduro',
#  'nomeia',
#  'novo',
#  'vice-presidente',
#  'e',
#  'troca……',
#  'https://t.co/BPMWBODUM2',
#  '#beta',
#  '#betalab',
#  '#mg',
#  'Revista',
#  'encontra',
#  'armas',
#  'e',
#  'drogas:',
#  'Rifle,',
#  '42',
#  'facas',
#  'e',
#  'roteador',
#  'são',
#  'achados',
#  'em……',
#  'https://t.co/TlIOyQeKb0',
#  '#beta',
#  '#betalab',
#  '#mg',
#  'Rio',
#  'reforçou',
#  'Operação',
#  'Praia:',
#  'Sábado',
#  'de',
#  'calor',
#  'tem',
#  'confusão',
#  'e',
#  'roubo',
#  'nas…',
#  'https://t.co/TwU41FTyfq…',
#  'https://t.co/fSPlWFWWVo',
#  '#beta',
#  '#betalab',
#  '#mg',
#  'Segundo',
#  'agentes',
#  'penitenciários:',
#  'Presídios',
#  'do',
#  'RJ',
#  'estão',
#  'em',
#  'alerta',
#  'desde…',
#  'https://t.co/jODEM3J6Y4…',
#  'https://t.co/gLMfJEuCNS',
#  '#beta',
#  '#betalab',
#  '#mg',
#  "'Tinha",
#  'que',
#  'matar',
#  "mais':",
#  'Secretário',
#  'de',
#  'Temer',
#  'deixa',
#  'cargo',
#  'após',
#  'dizer',
#  'que…',
#  'https://t.co/ZZm1TCutjz…',
#  'https://t.co/OoJJ3GcokW',
#  '#beta',
#  '#betalab',
#  '#mg',
#  'UOL',
#  'Confere',
#  'a',
#  'crise',
#  'prisional:',
#  'Gestão',
#  'privada',
#  'de',
#  'presídio',
#  'não',
#  'exime…',
#  'https://t.co/dj5fy2PIwi…',
#  'https://t.co/wCmH4Qhxt7',
#  '#beta',
#  '#betalab',
#  '#mg',
#  'UOL',
#  'Confere:',
#  'Governo',
#  'Temer',
#  'distorce',
#  'dados',
#  'econômicos',
#  'em',
#  'propaganda',
#  'de',
#  '120……',
#  'https://t.co/w4dzb3AgfT',
#  '#BRASILestáCHEIOdeMAMÃEsouFODA',
#  ...]

# %% [markdown]
# **Encontrando a frequencia do token 'Minas' e 'Pimental'**

# %%
tweets_text_nltk.count('Minas')
# Out:
# 2626

# %%
tweets_text_nltk.count('Pimentel')
# Out:
# 418

# %%
palavra_percentual(tweets_text_nltk.count('Minas'), list_palavras)
# Out:
# 1.9842679139495696

# %%
palavra_percentual(tweets_text_nltk.count('Pimentel'), list_palavras)
# Out:
# 0.3158507189759787

# %% [markdown]
# ** Similaridade de palavras por contextos**

# %%
tweets_text_nltk.similar('Minas')
# Out:
# mg rt drogas roubo estado o fora bh pimentel anos que governo sp
# manaus um calamidade casos segurança temer presídio

# %%
tweets_text_nltk.similar('Gerais')
# Out:
# rt que politica e para economia governador é não do no mantém melhor
# deste de com governo tem q o

# %%
tweets_text_nltk.similar('Pimentel')
# Out:
# minas rt governador estado mg o que fora drogas e anos mas calamidade
# né resolver ensino gerais é com em

# %% [markdown]
# ** Conjuntos de Palavras empregadas similarmente**

# %%
print(';'.join(tweets_text_nltk.collocation_list()))
# Out:
# dois helicópteros;febre amarela;Minas Gerais;calamidade financeira,;compra mais;helicópteros!!A cara;@AnaPaulaVolei: Mais;estado. htt…;avisa Justiça;calamidade financeira;canalhice ainda;mais dois;são maiores;tem recursos;três anos,;Com três;conta judicial;anos, presídio;presídio privado;21,8 milhões:

# %%
#obtem a frequencia de cada palavra
fdist=nltk.FreqDist(p.lower()for p in list_palavras)

# %%
fdist.most_common(20)
# Out:
# [('de', 8624),
#  ('em', 4478),
#  ('rt', 3080),
#  ('minas', 2945),
#  ('e', 2269),
#  ('estado', 2120),
#  ('mg', 2004),
#  ('-', 1937),
#  ('a', 1889),
#  ('governo', 1775),
#  ('o', 1737),
#  ('do', 1477),
#  ('é', 1289),
#  ('que', 1230),
#  ('mais', 1157),
#  ('gerais', 980),
#  ('drogas', 917),
#  ('com', 913),
#  ('compra', 886),
#  ('calamidade', 882)]

# %% [markdown]
# ** Removendo Stopwords**

# %%
stopwords=set(nltk.corpus.stopwords.words('portuguese'))

# %%
stopwords
# Out:
# {'a',
#  'ao',
#  'aos',
#  'aquela',
#  'aquelas',
#  'aquele',
#  'aqueles',
#  'aquilo',
#  'as',
#  'até',
#  'com',
#  'como',
#  'da',
#  'das',
#  'de',
#  'dela',
#  'delas',
#  'dele',
#  'deles',
#  'depois',
#  'do',
#  'dos',
#  'e',
#  'ela',
#  'elas',
#  'ele',
#  'eles',
#  'em',
#  'entre',
#  'era',
#  'eram',
#  'essa',
#  'essas',
#  'esse',
#  'esses',
#  'esta',
#  'estamos',
#  'estas',
#  'estava',
#  'estavam',
#  'este',
#  'esteja',
#  'estejam',
#  'estejamos',
#  'estes',
#  'esteve',
#  'estive',
#  'estivemos',
#  'estiver',
#  'estivera',
#  'estiveram',
#  'estiverem',
#  'estivermos',
#  'estivesse',
#  'estivessem',
#  'estivéramos',
#  'estivéssemos',
#  'estou',
#  'está',
#  'estávamos',
#  'estão',
#  'eu',
#  'foi',
#  'fomos',
#  'for',
#  'fora',
#  'foram',
#  'forem',
#  'formos',
#  'fosse',
#  'fossem',
#  'fui',
#  'fôramos',
#  'fôssemos',
#  'haja',
#  'hajam',
#  'hajamos',
#  'havemos',
#  'hei',
#  'houve',
#  'houvemos',
#  'houver',
#  'houvera',
#  'houveram',
#  'houverei',
#  'houverem',
#  'houveremos',
#  'houveria',
#  'houveriam',
#  'houvermos',
#  'houverá',
#  'houverão',
#  'houveríamos',
#  'houvesse',
#  'houvessem',
#  'houvéramos',
#  'houvéssemos',
#  'há',
#  'hão',
#  'isso',
#  'isto',
#  'já',
#  'lhe',
#  'lhes',
#  'mais',
#  'mas',
#  'me',
#  'mesmo',
#  'meu',
#  'meus',
#  'minha',
#  'minhas',
#  'muito',
#  'na',
#  'nas',
#  'nem',
#  'no',
#  'nos',
#  'nossa',
#  'nossas',
#  'nosso',
#  'nossos',
#  'num',
#  'numa',
#  'não',
#  'nós',
#  'o',
#  'os',
#  'ou',
#  'para',
#  'pela',
#  'pelas',
#  'pelo',
#  'pelos',
#  'por',
#  'qual',
#  'quando',
#  'que',
#  'quem',
#  'se',
#  'seja',
#  'sejam',
#  'sejamos',
#  'sem',
#  'serei',
#  'seremos',
#  'seria',
#  'seriam',
#  'será',
#  'serão',
#  'seríamos',
#  'seu',
#  'seus',
#  'somos',
#  'sou',
#  'sua',
#  'suas',
#  'são',
#  'só',
#  'também',
#  'te',
#  'tem',
#  'temos',
#  'tenha',
#  'tenham',
#  'tenhamos',
#  'tenho',
#  'terei',
#  'teremos',
#  'teria',
#  'teriam',
#  'terá',
#  'terão',
#  'teríamos',
#  'teu',
#  'teus',
#  'teve',
#  'tinha',
#  'tinham',
#  'tive',
#  'tivemos',
#  'tiver',
#  'tivera',
#  'tiveram',
#  'tiverem',
#  'tivermos',
#  'tivesse',
#  'tivessem',
#  'tivéramos',
#  'tivéssemos',
#  'tu',
#  'tua',
#  'tuas',
#  'tém',
#  'tínhamos',
#  'um',
#  'uma',
#  'você',
#  'vocês',
#  'vos',
#  'à',
#  'às',
#  'é',
#  'éramos'}

# %% [markdown]
# ** Remove stopwords da lista de palavras**

# %%
list_palavras=[i.lower() for i in list_palavras if not i.lower() in stopwords]
print(list_palavras[:50])
# Out:
# ['���⛪', '@', 'catedral', 'santo', 'antônio', '-', 'governador', 'valadares/mg', 'https://t.co/jsbkamiquj', '�', '@', 'governador', 'valadares,', 'minas', 'gerais', 'https://t.co/b3thidjcsf', '��', '@', 'governador', 'valadares,', 'minas', 'gerais', 'https://t.co/dpkgzvr2qw', '���', 'https://t.co/bndso34qk0', '���', 'psol', 'vai', 'questionar', 'aumento', 'vereadores', 'prefeito', 'bh', 'justiça', '-', 'politica', '-', 'estado', 'minas', 'https://t.co/dmg7bgsek5', '"', 'bom', 'bandido', 'morto"', 'deputado', 'cabo', 'júlio', 'condenado', 'fica', 'inelegível']

# %%
len(list_palavras)
# Out:
# 97023

# %%
#obtem a frequencia de cada palavra
fdist=nltk.FreqDist(p.lower() for p in list_palavras)

# %%
fdist.most_common(20)
# Out:
# [('rt', 3080),
#  ('minas', 2945),
#  ('estado', 2120),
#  ('mg', 2004),
#  ('-', 1937),
#  ('governo', 1775),
#  ('gerais', 980),
#  ('drogas', 917),
#  ('compra', 886),
#  ('calamidade', 882),
#  ('dois', 879),
#  ('helicópteros', 804),
#  ('q', 672),
#  ('governador', 651),
#  ('presídio', 568),
#  ('febre', 549),
#  ('r$', 519),
#  ('amarela', 506),
#  ('pimentel', 465),
#  ('ainda', 461)]

# %% [markdown]
# # **Trabalhando com Bigrams e Trigrams**

# %% [markdown]
# * **n-grams** é uma sequencia continua de n itens para uma amostra de texto ou fala.
# * **Unigram** palavras únicas
#
# * **Bigrams** são pares de palavras.
# * **Trigrams** são trio de palavras.
# * **Palavas** juntas são também conhecidas como **Colocações**
#
# * Unigramns normalmente **não contém** muita informação quando se comparado com bigramns e trigrams.
# * Quanto mais palavras mais **contexto** sobre a estrutura da linguagem.
# * Você deve avaliar o uso de n-gramns levando isso em consideração no seu projeto.

# %%
from nltk import bigrams, trigrams

# %% [markdown]
# **Visualizando trigramns**

# %%
list(bigrams(['O rato','roeu','roupa','do rei','de roma']))
# Out:
# [('O rato', 'roeu'),
#  ('roeu', 'roupa'),
#  ('roupa', 'do rei'),
#  ('do rei', 'de roma')]

# %% [markdown]
# **Visualizando trigramns**

# %%
list(trigrams(['O rato','roeu','roupa','do rei','de roma']))
# Out:
# [('O rato', 'roeu', 'roupa'),
#  ('roeu', 'roupa', 'do rei'),
#  ('roupa', 'do rei', 'de roma')]

# %% [markdown]
# ** Imprimindo bigramns com a base de tweets**

# %%
print(list(nltk.bigrams(list_palavras)))
# Out:
# [('���⛪', '@'), ('@', 'catedral'), ('catedral', 'santo'), ('santo', 'antônio'), ('antônio', '-'), ('-', 'governador'), ('governador', 'valadares/mg'), ('valadares/mg', 'https://t.co/jsbkamiquj'), ('https://t.co/jsbkamiquj', '�'), ('�', '@'), ('@', 'governador'), ('governador', 'valadares,'), ('valadares,', 'minas'), ('minas', 'gerais'), ('gerais', 'https://t.co/b3thidjcsf'), ('https://t.co/b3thidjcsf', '��'), ('��', '@'), ('@', 'governador'), ('governador', 'valadares,'), ('valadares,', 'minas'), ('minas', 'gerais'), ('gerais', 'https://t.co/dpkgzvr2qw'), ('https://t.co/dpkgzvr2qw', '���'), ('���', 'https://t.co/bndso34qk0'), ('https://t.co/bndso34qk0', '���'), ('���', 'psol'), ('psol', 'vai'), ('vai', 'questionar'), ('questionar', 'aumento'), ('aumento', 'vereadores'), ('vereadores', 'prefeito'), ('prefeito', 'bh'), ('bh', 'justiça'), ('justiça', '-'), ('-', 'politica'), ('politica', '-'), ('-', 'estado'), ('estado', 'minas'), ('minas', 'https://t.co/dmg7bgsek5'), ('https://t.co/dmg7bgsek5', '"'), ('"', 'bom'), ('bom', 'bandido'), ('bandido', 'morto"'), ('morto"', 'deputado'), ('deputado', 'cabo'), ('cabo', 'júlio'), ('júlio', 'condenado'), ('condenado', 'fica'), ('fica', 'inelegível'), ('inelegível', '10'), ('10', 'anos'), ('anos', '-'), ('-', 'politica'), ('politica', '-'), ('-', 'estado'), ('estado', 'minas'), ('minas', 'https://t.co/3gfaqvrfhs'), ('https://t.co/3gfaqvrfhs', '"..e'), ('"..e', '25%'), ('25%', 'mineiros'), ('mineiros', 'dizem'), ('dizem', 'torcer'), ('torcer', 'time'), ('time', 'nenhum,mesmo'), ('nenhum,mesmo', 'dentro'), ('dentro', 'estado'), ('estado', 'atlético-mg'), ('atlético-mg', 'cruzeiro.'), ('cruzeiro.', 'pq?.."'), ('pq?.."', 'https://t.co/fn5evllqsr'), ('https://t.co/fn5evllqsr', '"a'), ('"a', 'gigantesca'), ('gigantesca', 'barba'), ('barba', 'mal"'), ('mal"', 'destaque'), ('destaque', 'caderno'), ('caderno', 'cultura'), ('cultura', 'estado'), ('estado', 'minas.'), ('minas.', 'https://t.co/pxnuriktlw'), ('https://t.co/pxnuriktlw', '"bb'), ('"bb', 'governo'), ('governo', 'minas'), ('minas', 'travam'), ('travam', 'disputa'), ('disputa', 'sobre'), ('sobre', 'depósitos'), ('depósitos', 'judiciais"'), ('judiciais"', 'https://t.co/cnmu2a2qo5'), ('https://t.co/cnmu2a2qo5', '"com'), ('"com', 'vcs'), ('vcs', 'bh'), ('bh', 'fica'), ('fica', 'pequena!"'), ('pequena!"', 'belo'), ('belo', 'horizonte'), ('horizonte', '(pron.'), ('(pron.', '[bɛloɾiˈzõntʃi][10])'), ('[bɛloɾiˈzõntʃi][10])', 'capital'), ('capital', 'estado'), ('estado', 'mg,'), ('mg,', 'área'), ('área', 'aproximadamente'), ('aproximadamente', '331'), ('331', 'km²'), ('km²', '"daí'), ('"daí', 'gente'), ('gente', 'visita'), ('visita', 'governador'), ('governador', 'valadares"'), ('valadares"', '"que'), ('"que', 'lugar'), ('lugar', 'eh'), ('eh', 'mãe?"'), ('mãe?"', '"mg,'), ('"mg,', 'gente'), ('gente', 'uns'), ('uns', 'parente'), ('parente', 'la"'), ('la"', 'mano'), ('mano', 'onde'), ('onde', 'q'), ('q', 'parente'), ('parente', '"é'), ('"é', 'bonita'), ('bonita', 'bonita..."'), ('bonita..."', '#latergram'), ('#latergram', '#ibituruna'), ('#ibituruna', '#home'), ('#home', '@'), ('@', 'governador'), ('governador', 'valadares,'), ('valadares,', 'minas'), ('minas', 'gerais'), ('gerais', 'https://t.co/y12ttnqpnh'), ('https://t.co/y12ttnqpnh', '"erro'), ('"erro', 'desconhecido"'), ('desconhecido"', 'mato!'), ('mato!', 'aliás,'), ('aliás,', 'secretaria'), ('secretaria', 'estadual'), ('estadual', 'fazenda'), ('fazenda', 'tá'), ('tá', 'assim...'), ('assim...', 'mg'), ('mg', 'precisa'), ('precisa', 'dinheiro'), ('dinheiro', 'não,'), ('não,', 'governador?'), ('governador?', '"la'), ('"la', 'la'), ('la', 'land:'), ('land:', 'cantando'), ('cantando', 'estações"'), ('estações"', 'arrasa'), ('arrasa', 'globo'), ('globo', 'ouro'), ('ouro', '-'), ('-', 'estado'), ('estado', 'minas'), ('minas', 'https://t.co/aq0ng1bp5f'), ('https://t.co/aq0ng1bp5f', 'https://t.co/ay3qlrvnte'), ('https://t.co/ay3qlrvnte', '"la'), ('"la', 'la'), ('la', 'land:'), ('land:', 'cantando'), ('c ...

# %% [markdown]
# ** Imprimindo trigramns com a base de tweets**

# %%
print(list(nltk.trigrams(list_palavras[:100])))
# Out:
# [('���⛪', '@', 'catedral'), ('@', 'catedral', 'santo'), ('catedral', 'santo', 'antônio'), ('santo', 'antônio', '-'), ('antônio', '-', 'governador'), ('-', 'governador', 'valadares/mg'), ('governador', 'valadares/mg', 'https://t.co/jsbkamiquj'), ('valadares/mg', 'https://t.co/jsbkamiquj', '�'), ('https://t.co/jsbkamiquj', '�', '@'), ('�', '@', 'governador'), ('@', 'governador', 'valadares,'), ('governador', 'valadares,', 'minas'), ('valadares,', 'minas', 'gerais'), ('minas', 'gerais', 'https://t.co/b3thidjcsf'), ('gerais', 'https://t.co/b3thidjcsf', '��'), ('https://t.co/b3thidjcsf', '��', '@'), ('��', '@', 'governador'), ('@', 'governador', 'valadares,'), ('governador', 'valadares,', 'minas'), ('valadares,', 'minas', 'gerais'), ('minas', 'gerais', 'https://t.co/dpkgzvr2qw'), ('gerais', 'https://t.co/dpkgzvr2qw', '���'), ('https://t.co/dpkgzvr2qw', '���', 'https://t.co/bndso34qk0'), ('���', 'https://t.co/bndso34qk0', '���'), ('https://t.co/bndso34qk0', '���', 'psol'), ('���', 'psol', 'vai'), ('psol', 'vai', 'questionar'), ('vai', 'questionar', 'aumento'), ('questionar', 'aumento', 'vereadores'), ('aumento', 'vereadores', 'prefeito'), ('vereadores', 'prefeito', 'bh'), ('prefeito', 'bh', 'justiça'), ('bh', 'justiça', '-'), ('justiça', '-', 'politica'), ('-', 'politica', '-'), ('politica', '-', 'estado'), ('-', 'estado', 'minas'), ('estado', 'minas', 'https://t.co/dmg7bgsek5'), ('minas', 'https://t.co/dmg7bgsek5', '"'), ('https://t.co/dmg7bgsek5', '"', 'bom'), ('"', 'bom', 'bandido'), ('bom', 'bandido', 'morto"'), ('bandido', 'morto"', 'deputado'), ('morto"', 'deputado', 'cabo'), ('deputado', 'cabo', 'júlio'), ('cabo', 'júlio', 'condenado'), ('júlio', 'condenado', 'fica'), ('condenado', 'fica', 'inelegível'), ('fica', 'inelegível', '10'), ('inelegível', '10', 'anos'), ('10', 'anos', '-'), ('anos', '-', 'politica'), ('-', 'politica', '-'), ('politica', '-', 'estado'), ('-', 'estado', 'minas'), ('estado', 'minas', 'https://t.co/3gfaqvrfhs'), ('minas', 'https://t.co/3gfaqvrfhs', '"..e'), ('https://t.co/3gfaqvrfhs', '"..e', '25%'), ('"..e', '25%', 'mineiros'), ('25%', 'mineiros', 'dizem'), ('mineiros', 'dizem', 'torcer'), ('dizem', 'torcer', 'time'), ('torcer', 'time', 'nenhum,mesmo'), ('time', 'nenhum,mesmo', 'dentro'), ('nenhum,mesmo', 'dentro', 'estado'), ('dentro', 'estado', 'atlético-mg'), ('estado', 'atlético-mg', 'cruzeiro.'), ('atlético-mg', 'cruzeiro.', 'pq?.."'), ('cruzeiro.', 'pq?.."', 'https://t.co/fn5evllqsr'), ('pq?.."', 'https://t.co/fn5evllqsr', '"a'), ('https://t.co/fn5evllqsr', '"a', 'gigantesca'), ('"a', 'gigantesca', 'barba'), ('gigantesca', 'barba', 'mal"'), ('barba', 'mal"', 'destaque'), ('mal"', 'destaque', 'caderno'), ('destaque', 'caderno', 'cultura'), ('caderno', 'cultura', 'estado'), ('cultura', 'estado', 'minas.'), ('estado', 'minas.', 'https://t.co/pxnuriktlw'), ('minas.', 'https://t.co/pxnuriktlw', '"bb'), ('https://t.co/pxnuriktlw', '"bb', 'governo'), ('"bb', 'governo', 'minas'), ('governo', 'minas', 'travam'), ('minas', 'travam', 'disputa'), ('travam', 'disputa', 'sobre'), ('disputa', 'sobre', 'depósitos'), ('sobre', 'depósitos', 'judiciais"'), ('depósitos', 'judiciais"', 'https://t.co/cnmu2a2qo5'), ('judiciais"', 'https://t.co/cnmu2a2qo5', '"com'), ('https://t.co/cnmu2a2qo5', '"com', 'vcs'), ('"com', 'vcs', 'bh'), ('vcs', 'bh', 'fica'), ('bh', 'fica', 'pequena!"'), ('fica', 'pequena!"', 'belo'), ('pequena!"', 'belo', 'horizonte'), ('belo', 'horizonte', '(pron.'), ('horizonte', '(pron.', '[bɛloɾiˈzõntʃi][10])'), ('(pron.', '[bɛloɾiˈzõntʃi][10])', 'capital')]
